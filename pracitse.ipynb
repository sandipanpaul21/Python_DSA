# %%
nums1 = [1,2]
nums2 = [3,4]

num_total = sorted(nums1+ nums2)

# %%
mid = len(num_total) // 2
mid
# Out:
# 2

# %%
if len(num_total) %2 != 0:
    print(num_total[mid])
else:
    print(num_total)
    print(mid)
    print((num_total[mid] + num_total[mid-1]) / 2)
# Out:
# [1, 2, 3, 4]
# 2
# 2.5
